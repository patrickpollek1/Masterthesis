# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
import os
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Context
# This dataset is created for prediction of Graduate Admissions from an Indian perspective.
#
# # Content
# The dataset contains several parameters which are considered important during the application for Masters Programs.
# The parameters included are :
#
# - GRE Scores ( out of 340 ) --> **GRE Score**
# - TOEFL Scores ( out of 120 ) --> **TOEFL Score**
# - University Rating ( out of 5 ) --> **University Rating**
# - Statement of Purpose --> **SOP**
# - Letter of Recommendation Strength ( out of 5 ) --> **LOR**
# - Undergraduate GPA ( out of 10 ) --> **CGPA**
# - Research Experience ( either 0 or 1 ) --> **Research**
# - Chance of Admit ( ranging from 0 to 1 ) --> **Chance of Admit**
#
# # Acknowledgements
# This dataset is inspired by the UCLA Graduate Dataset. The test scores and GPA are in the older format.
# The dataset is owned by Mohan S Acharya.
#
# # Inspiration
# This dataset was built with the purpose of helping students in shortlisting universities with their profiles. The predicted output gives them a fair idea about their chances for a particular university.
#
# # Citation
# Mohan S Acharya, Asfia Armaan, Aneeta S Antony : A Comparison of Regression Models for Prediction of Graduate Admissions, IEEE International Conference on Computational Intelligence in Data Science 2019

# %%
df_admission=pd.read_csv('./datasets/Admission/Admission_Predict_Ver1.1.csv')

# %%
df_admission
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84
#
# [500 rows x 9 columns]

# %%
# !pip install sdv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sdv
#   Downloading sdv-0.18.0-py2.py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Collecting copulas<0.9,>=0.8.0
#   Downloading copulas-0.8.0-py2.py3-none-any.whl (53 kB)
#      ---------------------------------------- 53.6/53.6 kB 2.7 MB/s eta 0:00:00
# Collecting sdmetrics<0.10,>=0.9.0
#   Downloading sdmetrics-0.9.2-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.7/140.7 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2,>=1.1.3 in c:\programdata\anaconda3\lib\site-packages (from sdv) (1.4.4)
# Collecting Faker<15,>=10
#   Downloading Faker-14.2.1-py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 8.1 MB/s eta 0:00:00
# Collecting rdt<2,>=1.3.0
#   Downloading rdt-1.3.0-py2.py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.6/63.6 kB ? eta 0:00:00
# Requirement already satisfied: tqdm<5,>=4.15 in c:\programdata\anaconda3\lib\site-packages (from sdv) (4.64.1)
# Collecting ctgan<0.8,>=0.7.0
#   Downloading ctgan-0.7.1-py2.py3-none-any.whl (26 kB)
# Collecting cloudpickle<3.0,>=2.1.0
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: graphviz<1,>=0.13.2 in c:\users\patrick\appdata\roaming\python\python39\site-packages (from sdv) (0.20.1)
# Collecting deepecho<0.5,>=0.4.0
#   Downloading deepecho-0.4.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy<2,>=1.20.0 in c:\users\patrick\appdata\roaming\python\python39\site-packages (from sdv) (1.23.5)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\programdata\anaconda3\lib\site-packages (from copulas<0.9,>=0.8.0->sdv) (3.5.2)
# Requirement already satisfied: scipy<2,>=1.5.4 in c:\programdata\anaconda3\lib\site-packages (from copulas<0.9,>=0.8.0->sdv) (1.9.1)
# Requirement already satisfied: torch<2,>=1.8.0 in c:\users\patrick\appdata\roaming\python\python39\site-packages (from ctgan<0.8,>=0.7.0->sdv) (1.10.1+cu113)
# Requirement already satisfied: packaging<22,>=20 in c:\programdata\anaconda3\lib\site-packages (from ctgan<0.8,>=0.7.0->sdv) (21.3)
# Requirement already satisfied: python-dateutil>=2.4 in c:\programdata\anaconda3\lib\site-packages (from Faker<15,>=10->sdv) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<2,>=1.1.3->sdv) (2022.1)
# Requirement already satisfied: psutil<6,>=5.7 in c:\programdata\anaconda3\lib\site-packages (from rdt<2,>=1.3.0->sdv) (5.9.0)
# Requirement already satisfied: scikit-learn<2,>=0.24 in c:\programdata\anaconda3\lib\site-packages (from rdt<2,>=1.3.0->sdv) (1.0.2)
# Collecting plotly<6,>=5.10.0
#   Downloading plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
#      --------------------------------------- 15.2/15.2 MB 29.7 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\patrick\appdata\roaming\python\python39\site-packages (from tqdm<5,>=4.15->sdv) (0.4.6)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\patrick\appdata\roaming\python\python39\site-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->copulas<0.9,>=0.8.0->sdv) (1.4.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly<6,>=5.10.0->sdmetrics<0.10,>=0.9.0->sdv) (8.0.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.4->Faker<15,>=10->sdv) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<2,>=0.24->rdt<2,>=1.3.0->sdv) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<2,>=0.24->rdt<2,>=1.3.0->sdv) (1.1.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch<2,>=1.8.0->ctgan<0.8,>=0.7.0->sdv) (4.3.0)
# Installing collected packages: plotly, cloudpickle, Faker, rdt, deepecho, copulas, sdmetrics, ctgan, sdv
# Successfully installed Faker-14.2.1 cloudpickle-2.2.1 copulas-0.8.0 ctgan-0.7.1 deepecho-0.4.0 plotly-5.13.1 rdt-1.3.0 sdmetrics-0.9.2 sdv-0.18.0
#   WARNING: The script faker.exe is installed in 'C:\Users\Patrick\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script ctgan.exe is installed in 'C:\Users\Patrick\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.

# %%
from sdv.tabular import GaussianCopula
model = GaussianCopula()
model.fit(df_admission)

# %%
sample = model.sample(20000)
sample.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0         126        322          106                  4  2.7   3.4  8.31
# 1          88        314          102                  1  2.1   1.2  7.53
# 2         223        302          109                  2  1.1   2.7  8.18
# 3         444        294           98                  2  2.1   4.2  8.02
# 4         390        307          106                  2  2.0   3.9  8.17
#
#    Research  Chance of Admit
# 0         1              0.69
# 1         1              0.55
# 2         0              0.50
# 3         0              0.55
# 4         0              0.44

# %%
def round_off_rating(number):
    """Round a number to the closest half integer.
    >>> round_off_rating(1.3)
    1.5
    >>> round_off_rating(2.6)
    2.5
    >>> round_off_rating(3.0)
    3.0
    >>> round_off_rating(4.1)
    4.0"""

    return round(number * 2) / 2

# %%
print(sample.columns)
sample['SOP']=round_off_rating(sample['SOP'])
sample['LOR ']=round_off_rating(sample['LOR '])
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
sample['SOP']
# Out:
# 0        2.5
# 1        2.0
# 2        1.0
# 3        2.0
# 4        2.0
#         ...
# 19995    5.0
# 19996    2.5
# 19997    3.5
# 19998    2.5
# 19999    3.5
# Name: SOP, Length: 20000, dtype: float64

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(sample.corr(), annot=True,cmap='YlOrBr')
# Out:
# <AxesSubplot:>

# %%
df_admission.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df_admission=df_admission.drop(columns=['Serial No.'])

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df_admission.corr(), annot=True,cmap='YlOrBr')
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="ticks")
sns.pairplot(df_admission)

# %%
df_admission_All=df_admission
df_admission_confounder=df_admission.drop(columns=['GRE Score'])

# %% [markdown]
# # With all the Data and no confounding Variables

# %%
X_all=df_admission_All.drop(columns=['Chance of Admit '])
y_all=df_admission_All[['Chance of Admit ']]

# %%
X_all
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y_all
# Out:
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 495              0.87
# 496              0.96
# 497              0.93
# 498              0.73
# 499              0.84
#
# [500 rows x 1 columns]

# %%
X_train_all, X_test_all = train_test_split(X_all, test_size=0.2,shuffle=False)
y_train_all, y_test_all = train_test_split(y_all, test_size=0.2,shuffle=False)

# %%
X_train_all
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
y_train_all.to_numpy().ravel()
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.65, 0.63, 0.62, 0.64, 0.7 ,
#        0.94, 0.95, 0.97, 0.94, 0.76, 0.44, 0.46, 0.54, 0.65, 0.74, 0.91,
#        0.9 , 0.94, 0.88, 0.64, 0.58, 0.52, 0.48, 0.46, 0.49, 0.53, 0.87,
#        0.91, 0.88, 0.86, 0.89, 0.82, 0.78, 0.76, 0.56, 0.78, 0.72, 0.7 ,
#        0.64, 0.64, 0.46, 0.36, 0.42, 0.48, 0.47, 0.54, 0.56, 0.52, 0.55,
#        0.61, 0.57, 0.68, 0.78, 0.94, 0.96, 0.93, 0.84, 0.74, 0.72, 0.74,
#        0.64, 0.44, 0.46, 0.5 , 0.96, 0.92, 0.92, 0.94, 0.76, 0.72, 0.66,
#        0.64, 0.74, 0.64, 0.38, 0.34, 0.44, 0.36, 0.42, 0.48, 0.86, 0.9 ,
#        0.79, 0.71, 0.64, 0.62, 0.57, 0.74, 0.69, 0.87, 0.91, 0.93, 0.68,
#        0.61, 0.69, 0.62, 0.72, 0.59, 0.66, 0.56, 0.45, 0.47, 0.71, 0.94,
#        0.94, 0.57, 0.61, 0.57, 0.64, 0.85, 0.78, 0.84, 0.92, 0.96, 0.77,
#        0.71, 0.79, 0.89, 0.82, 0.76, 0.71, 0.8 , 0.78, 0.84, 0.9 , 0.92,
#        0.97, 0.8 , 0.81, 0.75, 0.83, 0.96, 0.79, 0.93, 0.94, 0.86, 0.79,
#        0.8 , 0.77, 0.7 , 0.65, 0.61, 0.52, 0.57, 0.53, 0.67, 0.68, 0.81,
#        0.78, 0.65, 0.64, 0.64, 0.65, 0.68, 0.89, 0.86, 0.89, 0.87, 0.85,
#        0.9 , 0.82, 0.72, 0.73, 0.71, 0.71, 0.68, 0.75, 0.72, 0.89, 0.84,
#        0.93, 0.93, 0.88, 0.9 , 0.87, 0.86, 0.94, 0.77, 0.78, 0.73, 0.73,
#        0.7 , 0.72, 0.73, 0.72, 0.97, 0.97, 0.69, 0.57, 0.63, 0.66, 0.64,
#        0.68, 0.79, 0.82, 0.95, 0.96, 0.94, 0.93, 0.91, 0.85, 0.84, 0.74,
#        0.76, 0.75, 0.76, 0.71, 0.67, 0.61, 0.63, 0.64, 0.71, 0.82, 0.73,
#        0.74, 0.69, 0.64, 0.91, 0.88, 0.85, 0.86, 0.7 , 0.59, 0.6 , 0.65,
#        0.7 , 0.76, 0.63, 0.81, 0.72, 0.71, 0.8 , 0.77, 0.74, 0.7 , 0.71,
#        0.93, 0.85, 0.79, 0.76, 0.78, 0.77, 0.9 , 0.87, 0.71, 0.7 , 0.7 ,
#        0.75, 0.71, 0.72, 0.73, 0.83, 0.77, 0.72, 0.54, 0.49, 0.52, 0.58,
#        0.78, 0.89, 0.7 , 0.66, 0.67, 0.68, 0.8 , 0.81, 0.8 , 0.94, 0.93,
#        0.92, 0.89, 0.82, 0.79, 0.58, 0.56, 0.56, 0.64, 0.61, 0.68, 0.76,
#        0.86, 0.9 , 0.71, 0.62, 0.66, 0.65, 0.73, 0.62, 0.74, 0.79, 0.8 ,
#        0.69, 0.7 , 0.76, 0.84, 0.78, 0.67, 0.66, 0.65, 0.54, 0.58, 0.79,
#        0.8 , 0.75, 0.73, 0.72, 0.62, 0.67, 0.81, 0.63, 0.69, 0.8 , 0.43,
#        0.8 , 0.73, 0.75, 0.71, 0.73, 0.83, 0.72, 0.94, 0.81, 0.81, 0.75,
#        0.79, 0.58, 0.59, 0.47, 0.49, 0.47, 0.42, 0.57, 0.62, 0.74, 0.73,
#        0.64, 0.63, 0.59, 0.73, 0.79, 0.68, 0.7 , 0.81, 0.85, 0.93, 0.91,
#        0.69, 0.77, 0.86, 0.74, 0.57, 0.51, 0.67, 0.72, 0.89, 0.95, 0.79,
#        0.39, 0.38, 0.34, 0.47, 0.56, 0.71, 0.78, 0.73, 0.82, 0.62, 0.96,
#        0.96, 0.46, 0.53, 0.49, 0.76, 0.64, 0.71, 0.84, 0.77, 0.89, 0.82,
#        0.84, 0.91, 0.67, 0.95])

# %%
regr = MLPRegressor(hidden_layer_sizes=(20,20,60),max_iter=500,random_state=420,batch_size=30).fit(X_train_all, y_train_all.to_numpy().ravel())
np.mean(cross_val_score(regr, X_train_all, y_train_all, cv=5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.5697808567015072

# %%
regr.score(X_test_all, y_test_all.to_numpy().ravel())
# Out:
# 0.7154679114985525

# %%
regr.predict(X_test_all)
# Out:
# array([0.62567236, 0.6229675 , 0.78956957, 0.88272718, 0.64633099,
#        0.57440176, 0.78096413, 0.61085878, 0.56584672, 0.52841472,
#        0.5152152 , 0.77926813, 0.73707209, 0.75540642, 0.74378949,
#        0.77441247, 0.70509256, 0.69811066, 0.61971728, 0.58322567,
#        0.52033577, 0.76546261, 0.82969202, 0.93315507, 0.86886007,
#        0.87707069, 0.62846125, 0.69700349, 0.55192187, 0.89333081,
#        0.74278446, 0.80726026, 0.88850935, 0.72753838, 0.65310924,
#        0.54296166, 0.55279087, 0.53899769, 0.70904448, 0.53840042,
#        0.58719526, 0.64031148, 0.91662239, 0.89748747, 0.84701869,
#        0.88651349, 0.98681728, 0.76284964, 0.66927126, 0.68928483,
#        0.75822548, 0.89198622, 0.98423527, 0.68531718, 0.60564621,
#        0.50736112, 0.55119009, 0.51232757, 0.66056121, 0.8689324 ,
#        0.75615829, 0.66366191, 0.61035854, 0.66556113, 0.50469055,
#        0.66250676, 0.76090104, 0.77956908, 0.79913062, 0.86906242,
#        0.8459437 , 0.54902574, 0.89304329, 0.65793584, 0.68609858,
#        0.63176734, 0.60366048, 0.6896908 , 0.72638293, 0.85024727,
#        0.76205128, 0.75667606, 0.84206017, 0.73555963, 0.70159758,
#        0.62686298, 0.69699662, 0.7618321 , 0.74626752, 0.75574757,
#        0.64227414, 0.59773625, 0.59024836, 0.72897979, 0.69617796,
#        0.86511633, 0.96911107, 0.95160818, 0.65994835, 0.80026239])

# %%
y_test_all.to_numpy().ravel()
# Out:
# array([0.63, 0.66, 0.78, 0.91, 0.62, 0.52, 0.61, 0.58, 0.57, 0.61, 0.54,
#        0.56, 0.59, 0.49, 0.72, 0.76, 0.65, 0.52, 0.6 , 0.58, 0.42, 0.77,
#        0.73, 0.94, 0.91, 0.92, 0.71, 0.71, 0.69, 0.95, 0.74, 0.73, 0.86,
#        0.71, 0.64, 0.55, 0.58, 0.61, 0.67, 0.66, 0.53, 0.79, 0.92, 0.87,
#        0.92, 0.91, 0.93, 0.84, 0.8 , 0.79, 0.82, 0.89, 0.93, 0.73, 0.71,
#        0.59, 0.51, 0.37, 0.69, 0.89, 0.77, 0.68, 0.62, 0.57, 0.45, 0.54,
#        0.71, 0.78, 0.81, 0.86, 0.87, 0.64, 0.9 , 0.67, 0.67, 0.59, 0.62,
#        0.65, 0.71, 0.79, 0.8 , 0.78, 0.83, 0.71, 0.73, 0.7 , 0.68, 0.79,
#        0.76, 0.65, 0.67, 0.54, 0.53, 0.62, 0.68, 0.87, 0.96, 0.93, 0.73,
#        0.84])

# %%
mean_squared_error(regr.predict(X_test_all),y_test_all)
# Out:
# 0.005156094180682164

# %%
x=np.linspace(0.3,1,101) 
plt.scatter(regr.predict(X_test_all), y_test_all)
plt.plot(x,x,'r')
plt.show()

# %%
result = permutation_importance(
        regr, X_test_all, y_test_all, n_repeats=10, random_state=42, n_jobs=2
)

regr_all_importances = pd.Series(result.importances_mean,index=X_all.columns)

# %%
regr_all_importances
# Out:
# GRE Score            0.159918
# TOEFL Score          0.192268
# University Rating    0.044775
# SOP                  0.300045
# LOR                 -0.040611
# CGPA                 0.268459
# Research             0.091439
# dtype: float64

# %%
fig, ax = plt.subplots()
regr_all_importances.plot.bar(yerr=result.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %% [markdown]
# # With GRE Score as confounding variable

# %%
X_con=df_admission_confounder.drop(columns=['Chance of Admit '])
y_con=df_admission_confounder[['Chance of Admit ']]

# %%
X_con
# Out:
#      TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0            118                  4  4.5   4.5  9.65         1
# 1            107                  4  4.0   4.5  8.87         1
# 2            104                  3  3.0   3.5  8.00         1
# 3            110                  3  3.5   2.5  8.67         1
# 4            103                  2  2.0   3.0  8.21         0
# ..           ...                ...  ...   ...   ...       ...
# 495          108                  5  4.5   4.0  9.02         1
# 496          117                  5  5.0   5.0  9.87         1
# 497          120                  5  4.5   5.0  9.56         1
# 498          103                  4  4.0   5.0  8.43         0
# 499          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 6 columns]

# %%
X_train_con, X_test_con = train_test_split(X_con, test_size=0.2,shuffle=False)
y_train_con, y_test_con = train_test_split(y_con, test_size=0.2,shuffle=False)

# %%
regr_con = MLPRegressor(hidden_layer_sizes=(20,20,60),max_iter=500,random_state=420,batch_size=30).fit(X_train_con, y_train_con.to_numpy().ravel())
np.mean(cross_val_score(regr, X_train_con, y_train_con, cv=5))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.6668492291906296

# %%
regr_con.score(X_test_con, y_test_con.to_numpy().ravel())
# Out:
# 0.6706573001463059

# %%
mean_squared_error(regr_con.predict(X_test_con),y_test_con)
# Out:
# 0.005968121160285743

# %%
x=np.linspace(0.3,1,101) 
plt.scatter(regr_con.predict(X_test_con), y_test_con)
plt.plot(x,x,'r')
plt.show()

# %%
from sklearn.inspection import permutation_importance


result_con = permutation_importance(
    regr_con, X_test_con, y_test_con, n_repeats=10, random_state=42, n_jobs=2
)

regr_con_importances = pd.Series(result_con.importances_mean,index=X_con.columns)

# %%
regr_con_importances
# Out:
# TOEFL Score          0.302361
# University Rating    0.247274
# SOP                  0.034889
# LOR                  0.061659
# CGPA                -0.039238
# Research             0.065665
# dtype: float64

# %%
fig, ax = plt.subplots()
regr_con_importances.plot.bar(yerr=result_con.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
T_X_train_all = torch.tensor(X_train_con.values).to(torch.float32)
T_X_train_all.dtype
# Out:
# torch.float32

# %%
T_y_train_all = torch.tensor(y_train_con.values).to(torch.float32)
T_y_train_all.dtype
# Out:
# torch.float32

# %%
dataset = TensorDataset(T_X_train_all,T_y_train_all)
dataloader = DataLoader(dataset, batch_size=20, shuffle=True)

# %%
n_input, n_hidden, n_out, batch_size, learning_rate = 6, 50, 1, 10, 0.01

# %%
model = nn.Sequential(nn.Linear(n_input, 50),
                      nn.ReLU(),
                      nn.Linear(50, 20),
                      nn.ReLU(),
                      nn.Linear(20, 1),
                      nn.Sigmoid()
                      )
                    
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=6, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=20, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=20, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
loss_function = nn.MSELoss()
optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)

# %%
losses = []
T_X_test_con = torch.tensor(X_test_con.values).to(torch.float32)
y_test_pred = model(T_X_test_con)
for epoch in range(500
                  ):
    pred_y = model(T_X_train_all)
    loss = loss_function(pred_y, T_y_train_all)
    print(loss_function(model(T_X_test_con), y_test_pred))
    losses.append(loss.item())
    model.zero_grad()
    loss.backward()

    optimizer.step()

x=np.linspace(0.3,1,101) 
plt.scatter(y_test_pred.detach().numpy(), y_test_con)
plt.plot(x,x,'r')
plt.show()
# Out:
# tensor(0., grad_fn=<MseLossBackward0>)
# tensor(3.1476e-05, grad_fn=<MseLossBackward0>)
# tensor(9.5881e-11, grad_fn=<MseLossBackward0>)
# tensor(3.1423e-05, grad_fn=<MseLossBackward0>)
# tensor(3.7561e-10, grad_fn=<MseLossBackward0>)
# tensor(3.1374e-05, grad_fn=<MseLossBackward0>)
# tensor(8.4106e-10, grad_fn=<MseLossBackward0>)
# tensor(3.1324e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4880e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1279e-05, grad_fn=<MseLossBackward0>)
# tensor(2.3030e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1241e-05, grad_fn=<MseLossBackward0>)
# tensor(3.2866e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1200e-05, grad_fn=<MseLossBackward0>)
# tensor(4.4521e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1166e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7716e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1132e-05, grad_fn=<MseLossBackward0>)
# tensor(7.2739e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1103e-05, grad_fn=<MseLossBackward0>)
# tensor(8.9263e-09, grad_fn=<MseLossBackward0>)
# tensor(3.1076e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0736e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1055e-05, grad_fn=<MseLossBackward0>)
# tensor(1.2720e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1034e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4859e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1017e-05, grad_fn=<MseLossBackward0>)
# tensor(1.7154e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1004e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9612e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0992e-05, grad_fn=<MseLossBackward0>)
# tensor(2.2235e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0987e-05, grad_fn=<MseLossBackward0>)
# tensor(2.5010e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0982e-05, grad_fn=<MseLossBackward0>)
# tensor(2.7976e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0981e-05, grad_fn=<MseLossBackward0>)
# tensor(3.1079e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0981e-05, grad_fn=<MseLossBackward0>)
# tensor(3.4376e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0985e-05, grad_fn=<MseLossBackward0>)
# tensor(3.7833e-08, grad_fn=<MseLossBackward0>)
# tensor(3.0991e-05, grad_fn=<MseLossBackward0>)
# tensor(4.1474e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1001e-05, grad_fn=<MseLossBackward0>)
# tensor(4.5289e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1013e-05, grad_fn=<MseLossBackward0>)
# tensor(4.9299e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1030e-05, grad_fn=<MseLossBackward0>)
# tensor(5.3466e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1046e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7831e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1069e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2420e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1097e-05, grad_fn=<MseLossBackward0>)
# tensor(6.7200e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1126e-05, grad_fn=<MseLossBackward0>)
# tensor(7.2202e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1158e-05, grad_fn=<MseLossBackward0>)
# tensor(7.7383e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1189e-05, grad_fn=<MseLossBackward0>)
# tensor(8.2809e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1228e-05, grad_fn=<MseLossBackward0>)
# tensor(8.8459e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1267e-05, grad_fn=<MseLossBackward0>)
# tensor(9.4359e-08, grad_fn=<MseLossBackward0>)
# tensor(3.1313e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0050e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1357e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0689e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1410e-05, grad_fn=<MseLossBackward0>)
# tensor(1.1357e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1462e-05, grad_fn=<MseLossBackward0>)
# tensor(1.2047e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1521e-05, grad_fn=<MseLossBackward0>)
# tensor(1.2773e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1579e-05, grad_fn=<MseLossBackward0>)
# tensor(1.3522e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1643e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4304e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1707e-05, grad_fn=<MseLossBackward0>)
# tensor(1.5117e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1777e-05, grad_fn=<MseLossBackward0>)
# tensor(1.5963e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1851e-05, grad_fn=<MseLossBackward0>)
# tensor(1.6848e-07, grad_fn=<MseLossBackward0>)
# tensor(3.1928e-05, grad_fn=<MseLossBackward0>)
# tensor(1.7763e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2005e-05, grad_fn=<MseLossBackward0>)
# tensor(1.8715e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2086e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9708e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2171e-05, grad_fn=<MseLossBackward0>)
# tensor(2.0727e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2255e-05, grad_fn=<MseLossBackward0>)
# tensor(2.1786e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2346e-05, grad_fn=<MseLossBackward0>)
# tensor(2.2895e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2440e-05, grad_fn=<MseLossBackward0>)
# tensor(2.4053e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2539e-05, grad_fn=<MseLossBackward0>)
# tensor(2.5263e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2642e-05, grad_fn=<MseLossBackward0>)
# tensor(2.6501e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2743e-05, grad_fn=<MseLossBackward0>)
# tensor(2.7793e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2852e-05, grad_fn=<MseLossBackward0>)
# tensor(2.9130e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2961e-05, grad_fn=<MseLossBackward0>)
# tensor(3.0531e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3077e-05, grad_fn=<MseLossBackward0>)
# tensor(3.1974e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3192e-05, grad_fn=<MseLossBackward0>)
# tensor(3.3482e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3314e-05, grad_fn=<MseLossBackward0>)
# tensor(3.5033e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3434e-05, grad_fn=<MseLossBackward0>)
# tensor(3.6645e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3564e-05, grad_fn=<MseLossBackward0>)
# tensor(3.8328e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3693e-05, grad_fn=<MseLossBackward0>)
# tensor(4.0075e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3829e-05, grad_fn=<MseLossBackward0>)
# tensor(4.1880e-07, grad_fn=<MseLossBackward0>)
# tensor(3.3965e-05, grad_fn=<MseLossBackward0>)
# tensor(4.3751e-07, grad_fn=<MseLossBackward0>)
# tensor(3.4107e-05, grad_fn=<MseLossBackward0>)
# tensor(4.5678e-07, grad_fn=<MseLossBackward0>)
# tensor(3.4246e-05, grad_fn=<MseLossBackward0>)
# tensor(4.7673e-07, grad_fn=<MseLossBackward0>)
# tensor(3.4394e-05, grad_fn=<MseLossBackward0>)
# tensor(4.9756e-07, grad_fn=<MseLossBackward0>)
# tensor(3.4544e-05, grad_fn=<MseLossBackward0>)
# tensor(5.1919e-07, grad_fn=<MseLossBackward0>)
# tensor(3.4701e-05, grad_fn=<MseLossBackward0>)
# tensor(5.4142e-07, grad_fn=<MseLossBackward0>)
# tensor(3.4857e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6457e-07, grad_fn=<MseLossBackward0>)
# tensor(3.5017e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8819e-07, grad_fn=<MseLossBackward0>)
# tensor(3.5178e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1300e-07, grad_fn=<MseLossBackward0>)
# tensor(3.5348e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3846e-07, grad_fn=<MseLossBackward0>)
# tensor(3.5515e-05, grad_fn=<MseLossBackward0>)
# tensor(6.6457e-07, grad_fn=<MseLossBackward0>)
# tensor(3.5685e-05, grad_fn=<MseLossBackward0>)
# tensor(6.9143e-07, grad_fn=<MseLossBackward0>)
# tensor(3.5860e-05, grad_fn=<MseLossBackward0>)
# tensor(7.1964e-07, grad_fn=<MseLossBackward0>)
# tensor(3.6041e-05, grad_fn=<MseLossBackward0>)
# tensor(7.4866e-07, grad_fn=<MseLossBackward0>)
# tensor(3.6222e-05, grad_fn=<MseLossBackward0>)
# tensor(7.7857e-07, grad_fn=<MseLossBackward0>)
# tensor(3.6409e-05, grad_fn=<MseLossBackward0>)
# tensor(8.0920e-07, grad_fn=<MseLossBackward0>)
# tensor(3.6595e-05, grad_fn=<MseLossBackward0>)
# tensor(8.4128e-07, grad_fn=<MseLossBackward0>)
# tensor(3.6790e-05, grad_fn=<MseLossBackward0>)
# tensor(8.7372e-07, grad_fn=<MseLossBackward0>)
# tensor(3.6982e-05, grad_fn=<MseLossBackward0>)
# tensor(9.0768e-07, grad_fn=<MseLossBackward0>)
# tensor(3.7182e-05, grad_fn=<MseLossBackward0>)
# tensor(9.4234e-07, grad_fn=<MseLossBackward0>)
# tensor(3.7382e-05, grad_fn=<MseLossBackward0>)
# tensor(9.7812e-07, grad_fn=<MseLossBackward0>)
# tensor(3.7586e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0148e-06, grad_fn=<MseLossBackward0>)
# tensor(3.7791e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0529e-06, grad_fn=<MseLossBackward0>)
# tensor(3.8003e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0916e-06, grad_fn=<MseLossBackward0>)
# tensor(3.8214e-05, grad_fn=<MseLossBackward0>)
# tensor(1.1319e-06, grad_fn=<MseLossBackward0>)
# tensor(3.8432e-05, grad_fn=<MseLossBackward0>)
# tensor(1.1732e-06, grad_fn=<MseLossBackward0>)
# tensor(3.8652e-05, grad_fn=<MseLossBackward0>)
# tensor(1.2158e-06, grad_fn=<MseLossBackward0>)
# tensor(3.8877e-05, grad_fn=<MseLossBackward0>)
# tensor(1.2594e-06, grad_fn=<MseLossBackward0>)
# tensor(3.9101e-05, grad_fn=<MseLossBackward0>)
# tensor(1.3043e-06, grad_fn=<MseLossBackward0>)
# tensor(3.9331e-05, grad_fn=<MseLossBackward0>)
# tensor(1.3502e-06, grad_fn=<MseLossBackward0>)
# tensor(3.9560e-05, grad_fn=<MseLossBackward0>)
# tensor(1.3972e-06, grad_fn=<MseLossBackward0>)
# tensor(3.9795e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4452e-06, grad_fn=<MseLossBackward0>)
# tensor(4.0027e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4945e-06, grad_fn=<MseLossBackward0>)
# tensor(4.0267e-05, grad_fn=<MseLossBackward0>)
# tensor(1.5448e-06, grad_fn=<MseLossBackward0>)
# tensor(4.0504e-05, grad_fn=<MseLossBackward0>)
# tensor(1.5963e-06, grad_fn=<MseLossBackward0>)
# tensor(4.0746e-05, grad_fn=<MseLossBackward0>)
# tensor(1.6491e-06, grad_fn=<MseLossBackward0>)
# tensor(4.0992e-05, grad_fn=<MseLossBackward0>)
# tensor(1.7032e-06, grad_fn=<MseLossBackward0>)
# tensor(4.1237e-05, grad_fn=<MseLossBackward0>)
# tensor(1.7587e-06, grad_fn=<MseLossBackward0>)
# tensor(4.1489e-05, grad_fn=<MseLossBackward0>)
# tensor(1.8154e-06, grad_fn=<MseLossBackward0>)
# tensor(4.1742e-05, grad_fn=<MseLossBackward0>)
# tensor(1.8734e-06, grad_fn=<MseLossBackward0>)
# tensor(4.1998e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9323e-06, grad_fn=<MseLossBackward0>)
# tensor(4.2251e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9923e-06, grad_fn=<MseLossBackward0>)
# tensor(4.2509e-05, grad_fn=<MseLossBackward0>)
# tensor(2.0532e-06, grad_fn=<MseLossBackward0>)
# tensor(4.2764e-05, grad_fn=<MseLossBackward0>)
# tensor(2.1152e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3026e-05, grad_fn=<MseLossBackward0>)
# tensor(2.1793e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3290e-05, grad_fn=<MseLossBackward0>)
# tensor(2.2436e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3550e-05, grad_fn=<MseLossBackward0>)
# tensor(2.3095e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3817e-05, grad_fn=<MseLossBackward0>)
# tensor(2.3759e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4077e-05, grad_fn=<MseLossBackward0>)
# tensor(2.4435e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4342e-05, grad_fn=<MseLossBackward0>)
# tensor(2.5119e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4607e-05, grad_fn=<MseLossBackward0>)
# tensor(2.5819e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4875e-05, grad_fn=<MseLossBackward0>)
# tensor(2.6523e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5142e-05, grad_fn=<MseLossBackward0>)
# tensor(2.7240e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5410e-05, grad_fn=<MseLossBackward0>)
# tensor(2.7965e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5677e-05, grad_fn=<MseLossBackward0>)
# tensor(2.8696e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5942e-05, grad_fn=<MseLossBackward0>)
# tensor(2.9437e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6211e-05, grad_fn=<MseLossBackward0>)
# tensor(3.0183e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6472e-05, grad_fn=<MseLossBackward0>)
# tensor(3.0930e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6735e-05, grad_fn=<MseLossBackward0>)
# tensor(3.1684e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6998e-05, grad_fn=<MseLossBackward0>)
# tensor(3.2450e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7263e-05, grad_fn=<MseLossBackward0>)
# tensor(3.3227e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7527e-05, grad_fn=<MseLossBackward0>)
# tensor(3.4001e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7783e-05, grad_fn=<MseLossBackward0>)
# tensor(3.4774e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8041e-05, grad_fn=<MseLossBackward0>)
# tensor(3.5554e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8296e-05, grad_fn=<MseLossBackward0>)
# tensor(3.6344e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8554e-05, grad_fn=<MseLossBackward0>)
# tensor(3.7132e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8805e-05, grad_fn=<MseLossBackward0>)
# tensor(3.7912e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9054e-05, grad_fn=<MseLossBackward0>)
# tensor(3.8706e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9303e-05, grad_fn=<MseLossBackward0>)
# tensor(3.9498e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9546e-05, grad_fn=<MseLossBackward0>)
# tensor(4.0287e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9787e-05, grad_fn=<MseLossBackward0>)
# tensor(4.1069e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0024e-05, grad_fn=<MseLossBackward0>)
# tensor(4.1859e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0260e-05, grad_fn=<MseLossBackward0>)
# tensor(4.2638e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0491e-05, grad_fn=<MseLossBackward0>)
# tensor(4.3422e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0722e-05, grad_fn=<MseLossBackward0>)
# tensor(4.4200e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0947e-05, grad_fn=<MseLossBackward0>)
# tensor(4.4971e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1163e-05, grad_fn=<MseLossBackward0>)
# tensor(4.5741e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1382e-05, grad_fn=<MseLossBackward0>)
# tensor(4.6501e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1592e-05, grad_fn=<MseLossBackward0>)
# tensor(4.7254e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1799e-05, grad_fn=<MseLossBackward0>)
# tensor(4.7992e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1998e-05, grad_fn=<MseLossBackward0>)
# tensor(4.8722e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2196e-05, grad_fn=<MseLossBackward0>)
# tensor(4.9454e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2388e-05, grad_fn=<MseLossBackward0>)
# tensor(5.0167e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2570e-05, grad_fn=<MseLossBackward0>)
# tensor(5.0871e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2753e-05, grad_fn=<MseLossBackward0>)
# tensor(5.1563e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2924e-05, grad_fn=<MseLossBackward0>)
# tensor(5.2231e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3089e-05, grad_fn=<MseLossBackward0>)
# tensor(5.2889e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3250e-05, grad_fn=<MseLossBackward0>)
# tensor(5.3538e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3404e-05, grad_fn=<MseLossBackward0>)
# tensor(5.4179e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3554e-05, grad_fn=<MseLossBackward0>)
# tensor(5.4789e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3690e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5385e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3825e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5967e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3950e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6517e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4067e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7070e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4184e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7607e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4289e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8113e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4388e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8603e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4477e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9065e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4560e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9520e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4636e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9950e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4704e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0370e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4770e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0758e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4821e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1117e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4865e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1469e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4903e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1793e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4936e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2105e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4960e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2388e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4974e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2644e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4982e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2894e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4986e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3113e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4975e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3298e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4957e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3475e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4937e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3632e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4904e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3756e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4867e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3878e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4825e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3976e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4774e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4065e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4721e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4122e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4654e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4165e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4583e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4179e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4506e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4193e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4427e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4200e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4343e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4179e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4249e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4154e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4153e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4099e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4043e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4018e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3930e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3932e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3814e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3837e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3691e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3733e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3566e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3607e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3431e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3474e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3295e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3337e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3155e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3178e-06, grad_fn=<MseLossBackward0>)
# tensor(5.3006e-05, grad_fn=<MseLossBackward0>)
# tensor(6.3024e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2860e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2850e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2705e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2671e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2550e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2494e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2389e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2301e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2228e-05, grad_fn=<MseLossBackward0>)
# tensor(6.2117e-06, grad_fn=<MseLossBackward0>)
# tensor(5.2065e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1917e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1894e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1711e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1724e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1505e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1550e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1294e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1372e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1077e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1194e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0870e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1018e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0656e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0836e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0438e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0652e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0223e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0469e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0011e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0282e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9796e-06, grad_fn=<MseLossBackward0>)
# tensor(5.0096e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9577e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9905e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9352e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9713e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9148e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9527e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8937e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9332e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8734e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9144e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8530e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8951e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8334e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8766e-05, grad_fn=<MseLossBackward0>)
# tensor(5.8151e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8576e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7965e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8386e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7787e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8199e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7613e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8009e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7438e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7823e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7281e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7640e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7121e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7449e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6967e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7264e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6824e-06, grad_fn=<MseLossBackward0>)
# tensor(4.7081e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6682e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6896e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6543e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6715e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6425e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6536e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6312e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6358e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6210e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6185e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6111e-06, grad_fn=<MseLossBackward0>)
# tensor(4.6010e-05, grad_fn=<MseLossBackward0>)
# tensor(5.6021e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5841e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5944e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5673e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5870e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5504e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5808e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5339e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5747e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5175e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5698e-06, grad_fn=<MseLossBackward0>)
# tensor(4.5015e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5662e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4861e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5635e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4704e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5618e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4556e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5605e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4403e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5601e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4256e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5604e-06, grad_fn=<MseLossBackward0>)
# tensor(4.4110e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5612e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3968e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5639e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3830e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5666e-06, grad_fn=<MseLossBackward0>)
# tensor(4.3691e-05, grad_fn=<MseLossBackward0>)

# %%
# Out:
# tensor([[0.5000],
#         [0.6993],
#         [0.7014],
#         [0.5000],
#         [0.6048],
#         [0.6048],
#         [0.7561],
#         [0.7468],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.6634],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.7880],
#         [0.7327],
#         [0.7291],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.7466],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.7994],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.7152],
#         [0.6541],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.7381],
#         [0.6048],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.6048],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.7833],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.7452],
#         [0.7398],
#         [0.7160],
#         [0.7118],
#         [0.6888],
#         [0.6048],
#         [0.5764],
#         [0.5000],
#         [0.7885],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.7216],
#         [0.8338],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.7398],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.5000],
#         [0.7109],
#         [0.6048],
#         [0.5000],
#         [0.8175],
#         [0.6048],
#         [0.5000],
#         [0.5000],
#         [0.8193],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.5000],
#         [0.6048],
#         [0.8181]], grad_fn=<SigmoidBackward0>)

# %%
# !pip install -U skorch
# Out:
# Collecting skorch
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#   Downloading skorch-0.12.1-py3-none-any.whl (193 kB)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\programdata\anaconda3\lib\site-packages (from skorch) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from skorch) (1.20.3)
# Collecting tabulate>=0.7.7
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: tqdm>=4.14.0 in c:\programdata\anaconda3\lib\site-packages (from skorch) (4.62.3)
# Requirement already satisfied: scipy>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from skorch) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->skorch) (2.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.14.0->skorch) (0.4.4)
# Installing collected packages: tabulate, skorch
# Successfully installed skorch-0.12.1 tabulate-0.9.0

# %%
from skorch import NeuralNetRegressor

# %%
class MyModule(nn.Module):
    def __init__(self,num_units=10,nonlin=nn.ReLU()):
        super().__init__()

        self.dense0 = nn.Linear(6, num_units)
        self.nonlin = nonlin
        self.sig= nn.Sigmoid()
        self.dropout = nn.Dropout(0.5)
        self.dense1 = nn.Linear(num_units, num_units)
        self.output = nn.Linear(num_units, 1)


    def forward(self, X,**kwargs):
        X=X.float()
        X = self.nonlin(self.dense0(X))
        X = self.nonlin(self.dense1(X))
        X=self.output(X)
        X= self.sig(X)
        return X

# %%
net = NeuralNetRegressor(
    MyModule,
    max_epochs=200,
    train_split=None,
    lr=0.001,
    # Shuffle training data on each epoch
    iterator_train__shuffle=True,
)

# %%
X=X_train_con.to_numpy().astype('float32')
X
# Out:
# array([[118.  ,   4.  ,   4.5 ,   4.5 ,   9.65,   1.  ],
#        [107.  ,   4.  ,   4.  ,   4.5 ,   8.87,   1.  ],
#        [104.  ,   3.  ,   3.  ,   3.5 ,   8.  ,   1.  ],
#        ...,
#        [116.  ,   4.  ,   5.  ,   4.5 ,   9.45,   1.  ],
#        [103.  ,   3.  ,   3.5 ,   4.  ,   8.78,   0.  ],
#        [117.  ,   4.  ,   5.  ,   4.  ,   9.66,   1.  ]], dtype=float32)

# %%
y=y_train_con.to_numpy().ravel().astype('float32')
y
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.65, 0.63, 0.62, 0.64, 0.7 ,
#        0.94, 0.95, 0.97, 0.94, 0.76, 0.44, 0.46, 0.54, 0.65, 0.74, 0.91,
#        0.9 , 0.94, 0.88, 0.64, 0.58, 0.52, 0.48, 0.46, 0.49, 0.53, 0.87,
#        0.91, 0.88, 0.86, 0.89, 0.82, 0.78, 0.76, 0.56, 0.78, 0.72, 0.7 ,
#        0.64, 0.64, 0.46, 0.36, 0.42, 0.48, 0.47, 0.54, 0.56, 0.52, 0.55,
#        0.61, 0.57, 0.68, 0.78, 0.94, 0.96, 0.93, 0.84, 0.74, 0.72, 0.74,
#        0.64, 0.44, 0.46, 0.5 , 0.96, 0.92, 0.92, 0.94, 0.76, 0.72, 0.66,
#        0.64, 0.74, 0.64, 0.38, 0.34, 0.44, 0.36, 0.42, 0.48, 0.86, 0.9 ,
#        0.79, 0.71, 0.64, 0.62, 0.57, 0.74, 0.69, 0.87, 0.91, 0.93, 0.68,
#        0.61, 0.69, 0.62, 0.72, 0.59, 0.66, 0.56, 0.45, 0.47, 0.71, 0.94,
#        0.94, 0.57, 0.61, 0.57, 0.64, 0.85, 0.78, 0.84, 0.92, 0.96, 0.77,
#        0.71, 0.79, 0.89, 0.82, 0.76, 0.71, 0.8 , 0.78, 0.84, 0.9 , 0.92,
#        0.97, 0.8 , 0.81, 0.75, 0.83, 0.96, 0.79, 0.93, 0.94, 0.86, 0.79,
#        0.8 , 0.77, 0.7 , 0.65, 0.61, 0.52, 0.57, 0.53, 0.67, 0.68, 0.81,
#        0.78, 0.65, 0.64, 0.64, 0.65, 0.68, 0.89, 0.86, 0.89, 0.87, 0.85,
#        0.9 , 0.82, 0.72, 0.73, 0.71, 0.71, 0.68, 0.75, 0.72, 0.89, 0.84,
#        0.93, 0.93, 0.88, 0.9 , 0.87, 0.86, 0.94, 0.77, 0.78, 0.73, 0.73,
#        0.7 , 0.72, 0.73, 0.72, 0.97, 0.97, 0.69, 0.57, 0.63, 0.66, 0.64,
#        0.68, 0.79, 0.82, 0.95, 0.96, 0.94, 0.93, 0.91, 0.85, 0.84, 0.74,
#        0.76, 0.75, 0.76, 0.71, 0.67, 0.61, 0.63, 0.64, 0.71, 0.82, 0.73,
#        0.74, 0.69, 0.64, 0.91, 0.88, 0.85, 0.86, 0.7 , 0.59, 0.6 , 0.65,
#        0.7 , 0.76, 0.63, 0.81, 0.72, 0.71, 0.8 , 0.77, 0.74, 0.7 , 0.71,
#        0.93, 0.85, 0.79, 0.76, 0.78, 0.77, 0.9 , 0.87, 0.71, 0.7 , 0.7 ,
#        0.75, 0.71, 0.72, 0.73, 0.83, 0.77, 0.72, 0.54, 0.49, 0.52, 0.58,
#        0.78, 0.89, 0.7 , 0.66, 0.67, 0.68, 0.8 , 0.81, 0.8 , 0.94, 0.93,
#        0.92, 0.89, 0.82, 0.79, 0.58, 0.56, 0.56, 0.64, 0.61, 0.68, 0.76,
#        0.86, 0.9 , 0.71, 0.62, 0.66, 0.65, 0.73, 0.62, 0.74, 0.79, 0.8 ,
#        0.69, 0.7 , 0.76, 0.84, 0.78, 0.67, 0.66, 0.65, 0.54, 0.58, 0.79,
#        0.8 , 0.75, 0.73, 0.72, 0.62, 0.67, 0.81, 0.63, 0.69, 0.8 , 0.43,
#        0.8 , 0.73, 0.75, 0.71, 0.73, 0.83, 0.72, 0.94, 0.81, 0.81, 0.75,
#        0.79, 0.58, 0.59, 0.47, 0.49, 0.47, 0.42, 0.57, 0.62, 0.74, 0.73,
#        0.64, 0.63, 0.59, 0.73, 0.79, 0.68, 0.7 , 0.81, 0.85, 0.93, 0.91,
#        0.69, 0.77, 0.86, 0.74, 0.57, 0.51, 0.67, 0.72, 0.89, 0.95, 0.79,
#        0.39, 0.38, 0.34, 0.47, 0.56, 0.71, 0.78, 0.73, 0.82, 0.62, 0.96,
#        0.96, 0.46, 0.53, 0.49, 0.76, 0.64, 0.71, 0.84, 0.77, 0.89, 0.82,
#        0.84, 0.91, 0.67, 0.95], dtype=float32)

# %%
net.fit(X,y.reshape(-1, 1))
x=np.linspace(0.3,1,101) 
plt.scatter(net.predict(X_test_con.to_numpy().astype('float32')), y_test_con.to_numpy().ravel().astype('float32'))
plt.plot(x,x,'r')
plt.show()
# Out:
# Re-initializing module.
# Re-initializing criterion.
# Re-initializing optimizer.
#   epoch    train_loss     dur
# -------  ------------  ------
#       1        0.0484  0.0081
#       2        0.0467  0.0060
#       3        0.0453  0.0060
#       4        0.0436  0.0068
#       5        0.0421  0.0000
#       6        0.0406  0.0169
#       7        0.0391  0.0006
#       8        0.0375  0.0000
#       9        0.0361  0.0055
#      10        0.0347  0.0105
#      11        0.0333  0.0000
#      12        0.0320  0.0000
#      13        0.0309  0.0004
#      14        0.0297  0.0000
#      15        0.0286  0.0166
#      16        0.0276  0.0000
#      17        0.0266  0.0166
#      18        0.0256  0.0168
#      19        0.0248  0.0165
#      20        0.0241  0.0055
#      21        0.0235  0.0107
#      22        0.0228  0.0000
#      23        0.0222  0.0000
#      24        0.0218  0.0167
#      25        0.0214  0.0000
#      26        0.0210  0.0166
#      27        0.0207  0.0000
#      28        0.0204  0.0167
#      29        0.0203  0.0000
#      30        0.0200  0.0174
#      31        0.0199  0.0000
#      32        0.0197  0.0000
#      33        0.0196  0.0063
#      34        0.0195  0.0000
#      35        0.0195  0.0107
#      36        0.0194  0.0000
#      37        0.0193  0.0167
#      38        0.0193  0.0000
#      39        0.0192  0.0167
#      40        0.0192  0.0000
#      41        0.0192  0.0156
#      42        0.0191  0.0022
#      43        0.0191  0.0000
#      44        0.0191  0.0154
#      45        0.0191  0.0000
#      46        0.0191  0.0167
#      47        0.0191  0.0060
#      48        0.0191  0.0115
#      49        0.0191  0.0000
#      50        0.0191  0.0169
#      51        0.0191  0.0000
#      52        0.0191  0.0000
#      53        0.0191  0.0168
#      54        0.0191  0.0000
#      55        0.0191  0.0155
#      56        0.0191  0.0000
#      57        0.0191  0.0166
#      58        0.0191  0.0000
#      59        0.0191  0.0167
#      60        0.0190  0.0060
#      61        0.0191  0.0095
#      62        0.0191  0.0000
#      63        0.0191  0.0000
#      64        0.0190  0.0167
#      65        0.0190  0.0000
#      66        0.0190  0.0166
#      67        0.0191  0.0000
#      68        0.0190  0.0166
#      69        0.0190  0.0000
#      70        0.0190  0.0167
#      71        0.0190  0.0000
#      72        0.0190  0.0228
#      73        0.0190  0.0107
#      74        0.0190  0.0000
#      75        0.0190  0.0164
#      76        0.0190  0.0000
#      77        0.0190  0.0168
#      78        0.0190  0.0000
#      79        0.0190  0.0174
#      80        0.0190  0.0000
#      81        0.0190  0.0000
#      82        0.0190  0.0159
#      83        0.0190  0.0000
#      84        0.0190  0.0166
#      85        0.0190  0.0065
#      86        0.0190  0.0109
#      87        0.0190  0.0000
#      88        0.0190  0.0150
#      89        0.0190  0.0000
#      90        0.0190  0.0000
#      91        0.0190  0.0011
#      92        0.0190  0.0000
#      93        0.0190  0.0166
#      94        0.0190  0.0000
#      95        0.0190  0.0166
#      96        0.0190  0.0000
#      97        0.0190  0.0162
#      98        0.0190  0.0065
#      99        0.0190  0.0098
#     100        0.0190  0.0000
#     101        0.0190  0.0166
#     102        0.0190  0.0000
#     103        0.0190  0.0000
#     104        0.0190  0.0011
#     105        0.0190  0.0000
#     106        0.0190  0.0166
#     107        0.0190  0.0168
#     108        0.0190  0.0000
#     109        0.0190  0.0166
#     110        0.0190  0.0000
#     111        0.0190  0.0111
#     112        0.0190  0.0000
#     113        0.0190  0.0152
#     114        0.0190  0.0000
#     115        0.0190  0.0000
#     116        0.0190  0.0010
#     117        0.0190  0.0000
#     118        0.0190  0.0177
#     119        0.0190  0.0000
#     120        0.0190  0.0156
#     121        0.0190  0.0000
#     122        0.0190  0.0178
#     123        0.0190  0.0055
#     124        0.0190  0.0100
#     125        0.0190  0.0000
#     126        0.0190  0.0162
#     127        0.0190  0.0000
#     128        0.0190  0.0156
#     129        0.0190  0.0000
#     130        0.0190  0.0000
#     131        0.0190  0.0167
#     132        0.0190  0.0000
#     133        0.0190  0.0212
#     134        0.0190  0.0070
#     135        0.0190  0.0040
#     136        0.0190  0.0071
#     137        0.0190  0.0090
#     138        0.0190  0.0000
#     139        0.0190  0.0000
#     140        0.0190  0.0157
#     141        0.0190  0.0000
#     142        0.0190  0.0166
#     143        0.0190  0.0167
#     144        0.0190  0.0000
#     145        0.0190  0.0167
#     146        0.0190  0.0000
#     147        0.0190  0.0070
#     148        0.0190  0.0000
#     149        0.0190  0.0095
#     150        0.0190  0.0000
#     151        0.0190  0.0166
#     152        0.0190  0.0000
#     153        0.0190  0.0156
#     154        0.0190  0.0000
#     155        0.0190  0.0000
#     156        0.0190  0.0167
#     157        0.0190  0.0000
#     158        0.0190  0.0172
#     159        0.0190  0.0000
#     160        0.0190  0.0154
#     161        0.0190  0.0060
#     162        0.0190  0.0050
#     163        0.0190  0.0030
#     164        0.0190  0.0000
#     165        0.0190  0.0158
#     166        0.0190  0.0000
#     167        0.0190  0.0165
#     168        0.0190  0.0000
#     169        0.0190  0.0167
#     170        0.0190  0.0000
#     171        0.0190  0.0000
#     172        0.0190  0.0010
#     173        0.0190  0.0000
#     174        0.0190  0.0176
#     175        0.0190  0.0070
#     176        0.0190  0.0083
#     177        0.0190  0.0000
#     178        0.0190  0.0000
#     179        0.0190  0.0166
#     180        0.0190  0.0000
#     181        0.0190  0.0167
#     182        0.0190  0.0000
#     183        0.0190  0.0167
#     184        0.0190  0.0000
#     185        0.0190  0.0000
#     186        0.0190  0.0167
#     187        0.0190  0.0000
#     188        0.0190  0.0167
#     189        0.0190  0.0167
#     190        0.0190  0.0000
#     191        0.0190  0.0179
#     192        0.0190  0.0000
#     193        0.0190  0.0153
#     194        0.0190  0.0000
#     195        0.0190  0.0156
#     196        0.0190  0.0004
#     197        0.0190  0.0000
#     198        0.0190  0.0158
#     199        0.0190  0.0000
#     200        0.0190  0.0166

# %%
from sklearn.model_selection import GridSearchCV

# deactivate skorch-internal train-valid split and verbose logging
net.set_params(train_split=False, verbose=0)
params = {
    'lr': [0.1,0.01,0.001,0.00001],
    'max_epochs': [100,500,1000,5000],
    'module__num_units': [30,50,70,100,150,200],
}
gs = GridSearchCV(net, params, refit=True, cv=5, scoring="r2", verbose=3)

gs.fit(X, y.reshape(-1, 1))
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5] END lr=0.1, max_epochs=100, module__num_units=30;, score=-3.644 total time=   0.3s
# [CV 2/5] END lr=0.1, max_epochs=100, module__num_units=30;, score=-2.812 total time=   0.4s
# [CV 3/5] END lr=0.1, max_epochs=100, module__num_units=30;, score=-4.375 total time=   0.4s
# [CV 4/5] END lr=0.1, max_epochs=100, module__num_units=30;, score=-50.402 total time=   0.4s
# [CV 5/5] END lr=0.1, max_epochs=100, module__num_units=30;, score=-3.953 total time=   0.3s
# [CV 1/5] END lr=0.1, max_epochs=100, module__num_units=50;, score=-3.644 total time=   0.4s
# [CV 2/5] END lr=0.1, max_epochs=100, module__num_units=50;, score=-2.812 total time=   0.4s
# [CV 3/5] END lr=0.1, max_epochs=100, module__num_units=50;, score=-48.417 total time=   0.4s
# [CV 4/5] END lr=0.1, max_epochs=100, module__num_units=50;, score=-6.869 total time=   0.4s
# [CV 5/5] END lr=0.1, max_epochs=100, module__num_units=50;, score=-3.953 total time=   0.4s
# [CV 1/5] END lr=0.1, max_epochs=100, module__num_units=70;, score=-3.644 total time=   0.4s
# [CV 2/5] END lr=0.1, max_epochs=100, module__num_units=70;, score=-2.812 total time=   0.4s
# [CV 3/5] END lr=0.1, max_epochs=100, module__num_units=70;, score=-48.417 total time=   0.4s
# [CV 4/5] END lr=0.1, max_epochs=100, module__num_units=70;, score=-50.403 total time=   0.4s
# [CV 5/5] END lr=0.1, max_epochs=100, module__num_units=70;, score=-3.953 total time=   0.4s
# [CV 1/5] END lr=0.1, max_epochs=100, module__num_units=100;, score=-17.391 total time=   0.4s
# [CV 2/5] END lr=0.1, max_epochs=100, module__num_units=100;, score=-2.812 total time=   0.4s
# [CV 3/5] END lr=0.1, max_epochs=100, module__num_units=100;, score=-4.375 total time=   0.4s
# [CV 4/5] END lr=0.1, max_epochs=100, module__num_units=100;, score=-6.869 total time=   0.4s
# [CV 5/5] END lr=0.1, max_epochs=100, module__num_units=100;, score=-3.953 total time=   0.4s
# [CV 1/5] END lr=0.1, max_epochs=100, module__num_units=150;, score=-3.644 total time=   0.5s
# [CV 2/5] END lr=0.1, max_epochs=100, module__num_units=150;, score=-2.812 total time=   0.5s
# [CV 3/5] END lr=0.1, max_epochs=100, module__num_units=150;, score=-48.417 total time=   0.5s
# [CV 4/5] END lr=0.1, max_epochs=100, module__num_units=150;, score=-50.403 total time=   0.5s
# [CV 5/5] END lr=0.1, max_epochs=100, module__num_units=150;, score=-3.953 total time=   0.5s
# [CV 1/5] END lr=0.1, max_epochs=100, module__num_units=200;, score=-3.644 total time=   0.5s
# [CV 2/5] END lr=0.1, max_epochs=100, module__num_units=200;, score=-2.812 total time=   0.5s
# [CV 3/5] END lr=0.1, max_epochs=100, module__num_units=200;, score=-4.375 total time=   0.4s
# [CV 4/5] END lr=0.1, max_epochs=100, module__num_units=200;, score=-6.869 total time=   0.5s
# [CV 5/5] END lr=0.1, max_epochs=100, module__num_units=200;, score=-3.953 total time=   0.5s
# [CV 1/5] END lr=0.1, max_epochs=500, module__num_units=30;, score=0.387 total time=   2.2s
# [CV 2/5] END lr=0.1, max_epochs=500, module__num_units=30;, score=-2.812 total time=   2.5s
# [CV 3/5] END lr=0.1, max_epochs=500, module__num_units=30;, score=-4.375 total time=   3.1s
# [CV 4/5] END lr=0.1, max_epochs=500, module__num_units=30;, score=-6.869 total time=   3.3s
# [CV 5/5] END lr=0.1, max_epochs=500, module__num_units=30;, score=-3.953 total time=   3.0s
# [CV 1/5] END lr=0.1, max_epochs=500, module__num_units=50;, score=-3.644 total time=   2.7s
# [CV 2/5] END lr=0.1, max_epochs=500, module__num_units=50;, score=-2.812 total time=   2.7s
# [CV 3/5] END lr=0.1, max_epochs=500, module__num_units=50;, score=-4.375 total time=   3.0s
# [CV 4/5] END lr=0.1, max_epochs=500, module__num_units=50;, score=-6.869 total time=   3.1s
# [CV 5/5] END lr=0.1, max_epochs=500, module__num_units=50;, score=-3.953 total time=   3.1s
# [CV 1/5] END lr=0.1, max_epochs=500, module__num_units=70;, score=-3.644 total time=   3.0s
# [CV 2/5] END lr=0.1, max_epochs=500, module__num_units=70;, score=-2.812 total time=   3.4s
# [CV 3/5] END lr=0.1, max_epochs=500, module__num_units=70;, score=-4.375 total time=   3.2s
# [CV 4/5] END lr=0.1, max_epochs=500, module__num_units=70;, score=-6.869 total time=   3.2s
# [CV 5/5] END lr=0.1, max_epochs=500, module__num_units=70;, score=-3.953 total time=   3.0s
# [CV 1/5] END lr=0.1, max_epochs=500, module__num_units=100;, score=-3.644 total time=   3.2s
# [CV 2/5] END lr=0.1, max_epochs=500, module__num_units=100;, score=-21.088 total time=   3.2s
# [CV 3/5] END lr=0.1, max_epochs=500, module__num_units=100;, score=-4.375 total time=   2.9s
# [CV 4/5] END lr=0.1, max_epochs=500, module__num_units=100;, score=-6.869 total time=   3.5s
# [CV 5/5] END lr=0.1, max_epochs=500, module__num_units=100;, score=-3.953 total time=   3.8s
# [CV 1/5] END lr=0.1, max_epochs=500, module__num_units=150;, score=-17.391 total time=   4.0s
# [CV 2/5] END lr=0.1, max_epochs=500, module__num_units=150;, score=-2.812 total time=   4.0s
# [CV 3/5] END lr=0.1, max_epochs=500, module__num_units=150;, score=-4.375 total time=   3.8s
# [CV 4/5] END lr=0.1, max_epochs=500, module__num_units=150;, score=-6.869 total time=   4.1s
# [CV 5/5] END lr=0.1, max_epochs=500, module__num_units=150;, score=-22.359 total time=   3.9s
# [CV 1/5] END lr=0.1, max_epochs=500, module__num_units=200;, score=-3.644 total time=   5.1s
# [CV 2/5] END lr=0.1, max_epochs=500, module__num_units=200;, score=-2.812 total time=   3.9s
# [CV 3/5] END lr=0.1, max_epochs=500, module__num_units=200;, score=-48.417 total time=   3.8s
# [CV 4/5] END lr=0.1, max_epochs=500, module__num_units=200;, score=-6.869 total time=   3.7s
# [CV 5/5] END lr=0.1, max_epochs=500, module__num_units=200;, score=-3.953 total time=   4.2s
# [CV 1/5] END lr=0.1, max_epochs=1000, module__num_units=30;, score=-3.643 total time=   6.1s
# [CV 2/5] END lr=0.1, max_epochs=1000, module__num_units=30;, score=-2.812 total time=   6.4s
# [CV 3/5] END lr=0.1, max_epochs=1000, module__num_units=30;, score=-4.375 total time=   6.9s
# [CV 4/5] END lr=0.1, max_epochs=1000, module__num_units=30;, score=-6.869 total time=   6.5s
# [CV 5/5] END lr=0.1, max_epochs=1000, module__num_units=30;, score=0.408 total time=   5.9s
# [CV 1/5] END lr=0.1, max_epochs=1000, module__num_units=50;, score=-3.644 total time=   6.5s
# [CV 2/5] END lr=0.1, max_epochs=1000, module__num_units=50;, score=-2.812 total time=   5.9s
# [CV 3/5] END lr=0.1, max_epochs=1000, module__num_units=50;, score=-4.375 total time=   6.4s
# [CV 4/5] END lr=0.1, max_epochs=1000, module__num_units=50;, score=-50.403 total time=   5.9s
# [CV 5/5] END lr=0.1, max_epochs=1000, module__num_units=50;, score=-3.953 total time=   5.9s
# [CV 1/5] END lr=0.1, max_epochs=1000, module__num_units=70;, score=-3.644 total time=   6.6s
# [CV 2/5] END lr=0.1, max_epochs=1000, module__num_units=70;, score=-21.088 total time=   6.0s
# [CV 3/5] END lr=0.1, max_epochs=1000, module__num_units=70;, score=-4.375 total time=   6.1s
# [CV 4/5] END lr=0.1, max_epochs=1000, module__num_units=70;, score=-6.869 total time=   6.0s
# [CV 5/5] END lr=0.1, max_epochs=1000, module__num_units=70;, score=-3.953 total time=   6.1s
# [CV 1/5] END lr=0.1, max_epochs=1000, module__num_units=100;, score=-3.644 total time=   6.8s
# [CV 2/5] END lr=0.1, max_epochs=1000, module__num_units=100;, score=-2.812 total time=   6.7s
# [CV 3/5] END lr=0.1, max_epochs=1000, module__num_units=100;, score=-4.375 total time=   7.5s
# [CV 4/5] END lr=0.1, max_epochs=1000, module__num_units=100;, score=-6.869 total time=   6.7s
# [CV 5/5] END lr=0.1, max_epochs=1000, module__num_units=100;, score=-3.953 total time=   6.1s
# [CV 1/5] END lr=0.1, max_epochs=1000, module__num_units=150;, score=-3.644 total time=   7.5s
# [CV 2/5] END lr=0.1, max_epochs=1000, module__num_units=150;, score=-21.088 total time=   8.7s
# [CV 3/5] END lr=0.1, max_epochs=1000, module__num_units=150;, score=-4.375 total time=   8.5s
# [CV 4/5] END lr=0.1, max_epochs=1000, module__num_units=150;, score=-6.869 total time=   8.0s
# [CV 5/5] END lr=0.1, max_epochs=1000, module__num_units=150;, score=-3.953 total time=   6.8s
# [CV 1/5] END lr=0.1, max_epochs=1000, module__num_units=200;, score=-3.644 total time=   7.7s
# [CV 2/5] END lr=0.1, max_epochs=1000, module__num_units=200;, score=-21.088 total time=   8.1s
# [CV 3/5] END lr=0.1, max_epochs=1000, module__num_units=200;, score=-4.375 total time=   8.4s
# [CV 4/5] END lr=0.1, max_epochs=1000, module__num_units=200;, score=-50.403 total time=   9.0s
# [CV 5/5] END lr=0.1, max_epochs=1000, module__num_units=200;, score=-3.953 total time=   7.6s
# [CV 1/5] END lr=0.1, max_epochs=5000, module__num_units=30;, score=-3.644 total time=  31.7s
# [CV 2/5] END lr=0.1, max_epochs=5000, module__num_units=30;, score=0.307 total time=  33.1s
# [CV 3/5] END lr=0.1, max_epochs=5000, module__num_units=30;, score=0.745 total time=  31.0s
# [CV 4/5] END lr=0.1, max_epochs=5000, module__num_units=30;, score=-6.869 total time=  32.3s
# [CV 5/5] END lr=0.1, max_epochs=5000, module__num_units=30;, score=-3.953 total time=  31.4s
# [CV 1/5] END lr=0.1, max_epochs=5000, module__num_units=50;, score=-3.644 total time=  32.5s
# [CV 2/5] END lr=0.1, max_epochs=5000, module__num_units=50;, score=-2.812 total time=  31.9s
# [CV 3/5] END lr=0.1, max_epochs=5000, module__num_units=50;, score=-48.417 total time=  33.6s
# [CV 4/5] END lr=0.1, max_epochs=5000, module__num_units=50;, score=-6.869 total time=  37.5s
# [CV 5/5] END lr=0.1, max_epochs=5000, module__num_units=50;, score=-3.953 total time=  31.9s
# [CV 1/5] END lr=0.1, max_epochs=5000, module__num_units=70;, score=-3.644 total time=  34.2s
# [CV 2/5] END lr=0.1, max_epochs=5000, module__num_units=70;, score=-2.812 total time=  33.5s
# [CV 3/5] END lr=0.1, max_epochs=5000, module__num_units=70;, score=-4.375 total time=  32.9s
# [CV 4/5] END lr=0.1, max_epochs=5000, module__num_units=70;, score=-6.869 total time=  34.8s
# [CV 5/5] END lr=0.1, max_epochs=5000, module__num_units=70;, score=-3.953 total time=  39.6s
# [CV 1/5] END lr=0.1, max_epochs=5000, module__num_units=100;, score=-3.644 total time=   0.4s
# [CV 2/5] END lr=0.1, max_epochs=5000, module__num_units=100;, score=-2.812 total time=   2.3s
# [CV 3/5] END lr=0.1, max_epochs=5000, module__num_units=100;, score=-48.417 total time=   0.2s

# %%
gs.best_estimator_
# Out:
# <class 'skorch.regressor.NeuralNetRegressor'>[initialized](
#   module_=MyModule(
#     (dense0): Linear(in_features=6, out_features=50, bias=True)
#     (nonlin): ReLU()
#     (sig): Sigmoid()
#     (dropout): Dropout(p=0.5, inplace=False)
#     (dense1): Linear(in_features=50, out_features=50, bias=True)
#     (output): Linear(in_features=50, out_features=1, bias=True)
#   ),
# )

# %%
x=np.linspace(0.3,1,101) 
plt.scatter(gs.best_estimator_.predict(X), y.reshape(-1, 1))
plt.plot(x,x,'r')
plt.show()

# %%
from tpot import TPOTRegressor

# %%
pipeline_optimizer = TPOTRegressor(generations=200, population_size=100, cv=3,verbosity=2,n_jobs=3)

# %%
pipeline_optimizer.fit(X, y)
# Out:
# Optimization Progress:   0%|          | 0/20100 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: -0.005209601251408458
#
# Generation 2 - Current best internal CV score: -0.005209601251408458
#
# Generation 3 - Current best internal CV score: -0.005209601251408458
#
# Generation 4 - Current best internal CV score: -0.005209601251408458
#
# Generation 5 - Current best internal CV score: -0.005209601251408458
#
# Generation 6 - Current best internal CV score: -0.005209601251408458
#
# Generation 7 - Current best internal CV score: -0.005209601251408458
#
# Generation 8 - Current best internal CV score: -0.005189032031295742
#
# Generation 9 - Current best internal CV score: -0.005189032031295742
#
# Generation 10 - Current best internal CV score: -0.005189032031295742
#
# Generation 11 - Current best internal CV score: -0.005034159797265988
#
# Generation 12 - Current best internal CV score: -0.005034159797265988
#
# Generation 13 - Current best internal CV score: -0.005034159797265988
#
# Generation 14 - Current best internal CV score: -0.005034159797265988
#
# Generation 15 - Current best internal CV score: -0.005034159797265988
#
# Generation 16 - Current best internal CV score: -0.005034159797265988
#
# Generation 17 - Current best internal CV score: -0.005034159797265988
#
# Generation 18 - Current best internal CV score: -0.005034159797265988
#
# Generation 19 - Current best internal CV score: -0.005034159797265988
#
# Generation 20 - Current best internal CV score: -0.005034159797265988
#
# Generation 21 - Current best internal CV score: -0.005034159797265988
#
# Generation 22 - Current best internal CV score: -0.005034159797265988
#
# Generation 23 - Current best internal CV score: -0.005034159797265988
#
# Generation 24 - Current best internal CV score: -0.005034159797265988
#
# Generation 25 - Current best internal CV score: -0.005034159797265988
#
# Generation 26 - Current best internal CV score: -0.005034159797265988
#
# Generation 27 - Current best internal CV score: -0.005034159797265988
#
# Generation 28 - Current best internal CV score: -0.005034159797265988
#
# Generation 29 - Current best internal CV score: -0.005034159797265988
#
# Generation 30 - Current best internal CV score: -0.005034159797265988
#
# Generation 31 - Current best internal CV score: -0.005034159797265988
#
# Generation 32 - Current best internal CV score: -0.00429369826533665
#
# Generation 33 - Current best internal CV score: -0.00429369826533665
#
# Generation 34 - Current best internal CV score: -0.00429369826533665
#
# Generation 35 - Current best internal CV score: -0.00429369826533665
#
# Generation 36 - Current best internal CV score: -0.00429369826533665
#
# Generation 37 - Current best internal CV score: -0.00429369826533665
#
# Generation 38 - Current best internal CV score: -0.00429369826533665
#
# Generation 39 - Current best internal CV score: -0.00429369826533665
#
# Generation 40 - Current best internal CV score: -0.00429369826533665
#
# Generation 41 - Current best internal CV score: -0.00429369826533665
#
# Generation 42 - Current best internal CV score: -0.00429369826533665
#
# Generation 43 - Current best internal CV score: -0.00429369826533665
#
# Generation 44 - Current best internal CV score: -0.00429369826533665
#
# Generation 45 - Current best internal CV score: -0.0042450289708840004
#
# Generation 46 - Current best internal CV score: -0.004134823776586804
#
# Generation 47 - Current best internal CV score: -0.004134823776586804
#
# Generation 48 - Current best internal CV score: -0.004101300000308961
#
# Generation 49 - Current best internal CV score: -0.004101300000308961
#
# Generation 50 - Current best internal CV score: -0.004101300000308961
#
# Generation 51 - Current best internal CV score: -0.004101300000308961
#
# Generation 52 - Current best internal CV score: -0.004101300000308961
#
# Generation 53 - Current best internal CV score: -0.004101300000308961
#
# Generation 54 - Current best internal CV score: -0.004101300000308961
#
# Generation 55 - Current best internal CV score: -0.004101300000308961
#
# Generation 56 - Current best internal CV score: -0.004101300000308961
#
# Generation 57 - Current best internal CV score: -0.004101300000308961
#
# Generation 58 - Current best internal CV score: -0.004101300000308961
#
# Generation 59 - Current best internal CV score: -0.004101300000308961
#
# Generation 60 - Current best internal CV score: -0.004101300000308961
#
# Generation 61 - Current best internal CV score: -0.004101300000308961
#
# Generation 62 - Current best internal CV score: -0.004101300000308961
#
# Generation 63 - Current best internal CV score: -0.004101300000308961
#
# Generation 64 - Current best internal CV score: -0.004101300000308961
#
# Generation 65 - Current best internal CV score: -0.004101300000308961
#
# Generation 66 - Current best internal CV score: -0.004101300000308961
#
# Generation 67 - Current best internal CV score: -0.004101300000308961
#
# Generation 68 - Current best internal CV score: -0.004101300000308961
#
# Generation 69 - Current best internal CV score: -0.004084329684897535
#
# Generation 70 - Current best internal CV score: -0.004084329684897535
#
# Generation 71 - Current best internal CV score: -0.00404645088910437
#
# Generation 72 - Current best internal CV score: -0.00404645088910437
#
# Generation 73 - Current best internal CV score: -0.00404645088910437
#
# Generation 74 - Current best internal CV score: -0.00404645088910437
#
# Generation 75 - Current best internal CV score: -0.00404645088910437
#
# Generation 76 - Current best internal CV score: -0.00404645088910437
#
# Generation 77 - Current best internal CV score: -0.00404645088910437
#
# Generation 78 - Current best internal CV score: -0.00404645088910437
#
# Generation 79 - Current best internal CV score: -0.00404645088910437
#
# Generation 80 - Current best internal CV score: -0.00404645088910437
#
# Generation 81 - Current best internal CV score: -0.00404645088910437
#
# Generation 82 - Current best internal CV score: -0.00404645088910437
#
# Generation 83 - Current best internal CV score: -0.00404645088910437
#
# Generation 84 - Current best internal CV score: -0.00404645088910437
#
# Generation 85 - Current best internal CV score: -0.00404645088910437
#
# Generation 86 - Current best internal CV score: -0.00404645088910437
#
# Generation 87 - Current best internal CV score: -0.00404645088910437
#
# Generation 88 - Current best internal CV score: -0.00404645088910437
#
# Generation 89 - Current best internal CV score: -0.00404645088910437
#
# Generation 90 - Current best internal CV score: -0.00404645088910437
#
# Generation 91 - Current best internal CV score: -0.00404645088910437
#
# Generation 92 - Current best internal CV score: -0.00404645088910437
#
# Generation 93 - Current best internal CV score: -0.00404645088910437
#
# Generation 94 - Current best internal CV score: -0.00404645088910437
#
# Generation 95 - Current best internal CV score: -0.00404645088910437
#
# Generation 96 - Current best internal CV score: -0.00404645088910437
#
# Generation 97 - Current best internal CV score: -0.00404645088910437
#
# Generation 98 - Current best internal CV score: -0.00404645088910437
#
# Generation 99 - Current best internal CV score: -0.00404645088910437
#
# Generation 100 - Current best internal CV score: -0.00404645088910437
#
# Generation 101 - Current best internal CV score: -0.00404645088910437
#
# Generation 102 - Current best internal CV score: -0.00404645088910437
#
# Generation 103 - Current best internal CV score: -0.00404645088910437
#
# Generation 104 - Current best internal CV score: -0.00404645088910437
#
# Generation 105 - Current best internal CV score: -0.00404645088910437
#
# Generation 106 - Current best internal CV score: -0.00404645088910437
#
# Generation 107 - Current best internal CV score: -0.00404645088910437
#
# Generation 108 - Current best internal CV score: -0.00404645088910437
#
# Generation 109 - Current best internal CV score: -0.00404645088910437
#
# Generation 110 - Current best internal CV score: -0.00404645088910437
#
# Generation 111 - Current best internal CV score: -0.00404645088910437
#
# Generation 112 - Current best internal CV score: -0.00404645088910437
#
# Generation 113 - Current best internal CV score: -0.00404645088910437
#
# Generation 114 - Current best internal CV score: -0.00404645088910437
#
# Generation 115 - Current best internal CV score: -0.00404645088910437
#
# Generation 116 - Current best internal CV score: -0.00404645088910437
#
# Generation 117 - Current best internal CV score: -0.00404645088910437
# Generation 118 - Current best internal CV score: -0.00404645088910437
#
# Generation 119 - Current best internal CV score: -0.00404645088910437
#
# Generation 120 - Current best internal CV score: -0.00404645088910437
#
# Generation 121 - Current best internal CV score: -0.00404645088910437
#
# Generation 122 - Current best internal CV score: -0.00404645088910437
#
# Generation 123 - Current best internal CV score: -0.00404645088910437
#
# Generation 124 - Current best internal CV score: -0.00404645088910437
#
# Generation 125 - Current best internal CV score: -0.00404645088910437
#
# Generation 126 - Current best internal CV score: -0.00404645088910437
#
# Generation 127 - Current best internal CV score: -0.00404645088910437
#
# Generation 128 - Current best internal CV score: -0.003884620227484712
#
# Generation 129 - Current best internal CV score: -0.003884620227484712
#
# Generation 130 - Current best internal CV score: -0.003884620227484712
#
# Generation 131 - Current best internal CV score: -0.003884620227484712
#
# Generation 132 - Current best internal CV score: -0.003884620227484712
#
# Generation 133 - Current best internal CV score: -0.003884620227484712
#
# Generation 134 - Current best internal CV score: -0.003884620227484712
#
# Generation 135 - Current best internal CV score: -0.003884620227484712
#
# Generation 136 - Current best internal CV score: -0.003884620227484712
#
# Generation 137 - Current best internal CV score: -0.003884620227484712
#
# Generation 138 - Current best internal CV score: -0.003884620227484712
#
# Generation 139 - Current best internal CV score: -0.003884620227484712
#
# Generation 140 - Current best internal CV score: -0.0037823369198094516
#
# Generation 141 - Current best internal CV score: -0.0037823369198094516
#
# Generation 142 - Current best internal CV score: -0.0037823369198094516
#
# Generation 143 - Current best internal CV score: -0.0037823369198094516
#
# Generation 144 - Current best internal CV score: -0.0037823369198094516
#
# Generation 145 - Current best internal CV score: -0.0037823369198094516
#
# Generation 146 - Current best internal CV score: -0.0037823369198094516
#
# Generation 147 - Current best internal CV score: -0.0037823369198094516
#
# Generation 148 - Current best internal CV score: -0.0037823369198094516
#
# Generation 149 - Current best internal CV score: -0.0037823369198094516
#
# Generation 150 - Current best internal CV score: -0.0037823369198094516
#
# Generation 151 - Current best internal CV score: -0.0037823369198094516
#
# Generation 152 - Current best internal CV score: -0.0037823369198094516
#
# Generation 153 - Current best internal CV score: -0.0037823369198094516
#
# Generation 154 - Current best internal CV score: -0.0037823369198094516
#
# Generation 155 - Current best internal CV score: -0.0037823369198094516
#
# Generation 156 - Current best internal CV score: -0.0037823369198094516
#
# Generation 157 - Current best internal CV score: -0.0037823369198094516
#
# Generation 158 - Current best internal CV score: -0.0037823369198094516
#
# Generation 159 - Current best internal CV score: -0.0037823369198094516
#
# Generation 160 - Current best internal CV score: -0.0037823369198094516
#
# Generation 161 - Current best internal CV score: -0.0037823369198094516
#
# Generation 162 - Current best internal CV score: -0.0037823369198094516
#
# Generation 163 - Current best internal CV score: -0.0037823369198094516
#
# Generation 164 - Current best internal CV score: -0.0037823369198094516
#
# Generation 165 - Current best internal CV score: -0.0037823369198094516
#
# Generation 166 - Current best internal CV score: -0.0037823369198094516
#
# Generation 167 - Current best internal CV score: -0.0037823369198094516
#
# Generation 168 - Current best internal CV score: -0.0037823369198094516
#
# Generation 169 - Current best internal CV score: -0.0037823369198094516
#
# Generation 170 - Current best internal CV score: -0.0037823369198094516
#
# Generation 171 - Current best internal CV score: -0.0037823369198094516
#
# Generation 172 - Current best internal CV score: -0.0037823369198094516
#
# Generation 173 - Current best internal CV score: -0.0037823369198094516
#
# Generation 174 - Current best internal CV score: -0.0037823369198094516
#
# Generation 175 - Current best internal CV score: -0.0037823369198094516
#
# Generation 176 - Current best internal CV score: -0.0037823369198094516
#
# Generation 177 - Current best internal CV score: -0.0037823369198094516
#
# Generation 178 - Current best internal CV score: -0.0037823369198094516
#
# Generation 179 - Current best internal CV score: -0.0037823369198094516
#
# Generation 180 - Current best internal CV score: -0.0037823369198094516
#
# Generation 181 - Current best internal CV score: -0.0037823369198094516
#
# Generation 182 - Current best internal CV score: -0.0037823369198094516
#
# Generation 183 - Current best internal CV score: -0.0037823369198094516
#
# Generation 184 - Current best internal CV score: -0.0037823369198094516
#
# Generation 185 - Current best internal CV score: -0.0037823369198094516
#
# Generation 186 - Current best internal CV score: -0.0037823369198094516
#
# Generation 187 - Current best internal CV score: -0.0037823369198094516
#
# Generation 188 - Current best internal CV score: -0.0037823369198094516
#
# Generation 189 - Current best internal CV score: -0.0037823369198094516
#
# Generation 190 - Current best internal CV score: -0.0037823369198094516
#
# Generation 191 - Current best internal CV score: -0.0037823369198094516
#
# Generation 192 - Current best internal CV score: -0.0037823369198094516
#
# Generation 193 - Current best internal CV score: -0.0037823369198094516
#
# Generation 194 - Current best internal CV score: -0.0037823369198094516
#
# Generation 195 - Current best internal CV score: -0.0037823369198094516
#
# Generation 196 - Current best internal CV score: -0.0037823369198094516
#
# Generation 197 - Current best internal CV score: -0.0037823369198094516
#
# Generation 198 - Current best internal CV score: -0.0037823369198094516
#
# Generation 199 - Current best internal CV score: -0.0037823369198094516
#
# Generation 200 - Current best internal CV score: -0.0037823369198094516
#
# Best pipeline: LinearSVR(CombineDFs(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), RandomForestRegressor(input_matrix, bootstrap=True, max_features=0.9500000000000001, min_samples_leaf=14, min_samples_split=14, n_estimators=100)), C=0.001, dual=True, epsilon=0.001, loss=epsilon_insensitive, tol=0.1)
# TPOTRegressor(cv=3, generations=200, n_jobs=3, verbosity=2)

# %%
x=np.linspace(0.3,1,101) 
plt.scatter(pipeline_optimizer.predict(X), y.reshape(-1, 1))
plt.plot(x,x,'r')
plt.show()

# %%
from sklearn.inspection import permutation_importance


result_con_auto_ml = permutation_importance(
    pipeline_optimizer, X_test_con, y_test_con.to_numpy().ravel().astype('float32'), n_repeats=10, random_state=42, n_jobs=2
)

regr_con_importances_auto_ml = pd.Series(result_con_auto_ml.importances_mean,index=X_con.columns)
print(regr_con_importances_auto_ml)
fig, ax = plt.subplots()
regr_con_importances.plot.bar(yerr=result_conresult_con_auto_ml.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but PolynomialFeatures was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\loky\backend\queues.py", line 153, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\loky\backend\reduction.py", line 271, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\loky\backend\reduction.py", line 264, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\cloudpickle\cloudpickle_fast.py", line 602, in dump
#     return Pickler.dump(self, obj)
# TypeError: cannot pickle '_hashlib.HASH' object
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6696\1227327841.py in <module>
#       2
#       3
# ----> 4 result_con_auto_ml = permutation_importance(
#       5     pipeline_optimizer, X_test_con, y_test_con.to_numpy().ravel().astype('float32'), n_repeats=10, random_state=42, n_jobs=2
#       6 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\inspection\_permutation_importance.py in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     257     baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
#     258
# --> 259     scores = Parallel(n_jobs=n_jobs)(
#     260         delayed(_calculate_permutation_scores)(
#     261             estimator,
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# C:\ProgramData\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     444                     raise CancelledError()
#     445                 elif self._state == FINISHED:
# --> 446                     return self.__get_result()
#     447                 else:
#     448                     raise TimeoutError()
#
# C:\ProgramData\Anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     389         if self._exception:
#     390             try:
# --> 391                 raise self._exception
#     392             finally:
#     393                 # Break a reference cycle with the exception in self._exception
#
# PicklingError: Could not pickle the task to send it to the workers.
